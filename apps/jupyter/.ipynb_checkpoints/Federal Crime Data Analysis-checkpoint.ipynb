# %% [markdown]
# # Steps in Creating a Data Science Project
#
# 1. Defining the project
# 2. Preparing the data
# 3. Exploratory data analysis & preprocessing
# 4. Creating and evaluating a machine learning model
# 5. Making predictions
# 6. Presenting your findings

# %% [markdown]
# # 1. Defining The Project
#
#     **Business problem description:**
#
#
#     **Technical problem description:**

# %% [markdown]
# # 2. Preparing the data
#
# # Setup Environment
#
#     Import libraries

# %%
import pandas as pd
import os

# plot libraries
from matplotlib.axis import Axis  
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import datetime

import numpy as np

# library helper
# run: importnb-install from Conda before using
from importnb import Notebook
with Notebook(): 
    import Utility

# custom helper class (from jupyter notebook)
helper = Utility.Helper()

# progress bars for long running functions
import tqdm

from scipy import stats

from sklearn.cluster import KMeans

import numpy.ma as ma

from IPython.display import Image
# Out:
# Class 'Helper' v1.1 has been loaded

# %% [markdown]
#     Function to reload changes in Jupyter notebooks

# %%
# reload notebooks
from importlib import reload
with Notebook(): __name__ == '__main__' and reload(Utility)

# %% [markdown]
#     Define constants and create control variables

# %%
DATA_PATH = '../../data/'

MIN_YEAR = 2009
MAX_YEAR = 2018
FILE_PREFIX = "OJJDP_"

FIGSIZE = (12,9)

#spectrum of chart colors
COLORS = ['#17becf', '#bcbd22', '#7f7f7f', '#e377c2', '#8c564b', '#9467bd', '#d62728', '#2ca02c', '#ff7f0e']

# %% [markdown]
# # Import Data
#     FBI provides federval-level historical data in single file

# %%
fbi_fed_file = DATA_PATH + "Table_01_Crime_in_the_United_States_by_Volume_and_Rate_per_100000_Inhabitants_2001-2020.csv"
    
fbi_fed_df = helper.create_df(fbi_fed_file)

fbi_fed_df.head()
# Out:
#    Year  Population1 Violent\ncrime2  Violent \ncrime \nrate   \
# 0  2001  285,317,559       1,439,480                    504.5
# 1  2002  287,973,924       1,423,677                    494.4
# 2  2003  290,788,976       1,383,676                    475.8
# 3  2004  293,656,842       1,360,088                    463.2
# 4  2005  296,507,061       1,390,745                    469.0
#
#   Murder and\nnonnegligent \nmanslaughter  \
# 0                                  16,037
# 1                                  16,229
# 2                                  16,528
# 3                                  16,148
# 4                                  16,740
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 0                                               5.6
# 1                                               5.6
# 2                                               5.7
# 3                                               5.5
# 4                                               5.6
#
#   Rape\n(revised \ndefinition)3  Rape\n(revised \ndefinition) \nrate3  \
# 0                           NaN                                   NaN
# 1                           NaN                                   NaN
# 2                           NaN                                   NaN
# 3                           NaN                                   NaN
# 4                           NaN                                   NaN
#
#   Rape\n(legacy \ndefinition)4  Rape\n(legacy \ndefinition) \nrate4  ...  \
# 0                       90,863                                 31.8  ...
# 1                       95,235                                 33.1  ...
# 2                       93,883                                 32.3  ...
# 3                       95,089                                 32.4  ...
# 4                       94,347                                 31.8  ...
#
#   Aggravated \nassault  Aggravated \nassault rate  Property \ncrime  \
# 0              909,023                       318.6       10,437,189
# 1              891,407                       309.5       10,455,277
# 2              859,030                       295.4       10,442,862
# 3              847,381                       288.6       10,319,386
# 4              862,220                       290.8       10,174,754
#
#    Property \ncrime \nrate    Burglary Burglary \nrate  Larceny-\ntheft  \
# 0                  3,658.10  2,116,531            741.8       7,092,267
# 1                  3,630.60  2,151,252            747.0       7,057,379
# 2                  3,591.20  2,154,834            741.0       7,026,802
# 3                  3,514.10  2,144,446            730.3       6,937,089
# 4                  3,431.50  2,155,448            726.9       6,783,447
#
#    Larceny-\ntheft rate  Motor \nvehicle \ntheft  \
# 0               2,485.70               1,228,391
# 1               2,450.70               1,246,646
# 2               2,416.50               1,261,226
# 3               2,362.30               1,237,851
# 4               2,287.80               1,235,859
#
#   Motor \nvehicle \ntheft \nrate
# 0                           430.5
# 1                           432.9
# 2                           433.7
# 3                           421.5
# 4                           416.8
#
# [5 rows x 22 columns]

# %% [markdown]
#     FBI also provides agency-level data, these have been collected via web scraper and stored as CSV files, by year

# %%
fbi_agency_file = DATA_PATH + "fbi_state_2019.csv"
    
fbi_agency_df = helper.create_df(fbi_agency_file)
fbi_agency_df.head()
# Out:
#      State State/Tribal/Other                                       Agency  \
# 0  Alabama    Tribal Agencies                          Poarch Creek Tribal
# 1   Alaska     State Agencies                        Alaska State Troopers
# 2   Alaska    Tribal Agencies                            Metlakatla Tribal
# 3   Alaska     Other Agencies              Fairbanks International Airport
# 4   Alaska     Other Agencies  Ted Stevens Anchorage International Airport
#
#   Unit/Office Violent crime  Murder and nonnegligent manslaughter  Rape  \
# 0         NaN            10                                   0.0     0
# 1         NaN         1,369                                  23.0   278
# 2         NaN             0                                   0.0     0
# 3         NaN             1                                   0.0     0
# 4         NaN             6                                   0.0     0
#
#   Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 0       5                  5            398        6           377
# 1      65              1,003          2,985    1,073         1,446
# 2       0                  0              0        0             0
# 3       0                  1             16        0            14
# 4       0                  6            107        8            83
#
#   Motor vehicle theft  Arson
# 0                  15    0.0
# 1                 466   47.0
# 2                   0    0.0
# 3                   2    0.0
# 4                  16    0.0

# %% [markdown]
#     Let's create a state dataframe, summarize stats for the agencies within each state

# %%
agency_columns = ['State/Tribal/Other', 'Agency', 'Unit/Office']

fbi_state_df = pd.DataFrame(columns = fbi_agency_df.columns.drop(labels=agency_columns), dtype = int)

curr_state = ""
curr_series = pd.Series(index = fbi_state_df.columns, dtype = int)

row_iterator = fbi_agency_df.iterrows()

# wrap function in progress bar
for i in tqdm.tqdm(range(0, fbi_agency_df.shape[0])):

     # grab the next row
    _, next_series = next(row_iterator)
    next_state = next_series['State']
    # drop non-numeric columns and type to integer
    next_series = next_series.drop(labels=agency_columns).drop(labels=['State']).replace(',','', regex=True).fillna(0).astype(int)

    # if the state is the same as the current state, add the rows
    if(curr_state == next_state):
        curr_series.add(next_series)      

    # otherwise, save the state as current
    else:
        curr_state = next_state
        curr_series = next_series   
    
    # in either case, append the series to the dataframe, we'll drop duplicates later
    fbi_state_series = pd.Series([curr_state], index=['State']).append(curr_series)
    fbi_state_df = fbi_state_df.append(fbi_state_series, ignore_index=True)
    
fbi_state_df = fbi_state_df.drop_duplicates(subset=['State'], keep='last')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1833/1833 [00:07<00:00, 261.63it/s]

# %%
fbi_state_df.head()
# Out:
#           State  Violent crime  Murder and nonnegligent manslaughter  Rape  \
# 0       Alabama             10                                     0     0
# 4        Alaska           1369                                    23   278
# 19      Arizona              2                                     0     0
# 22     Arkansas              1                                     0     0
# 188  California             43                                     0     0
#
#      Robbery  Aggravated assault  Property crime  Burglary  Larceny-theft  \
# 0          5                   5             398         6            377
# 4         65                1003            2985      1073           1446
# 19         0                   2               7         2              4
# 22         0                   1               7         1              5
# 188        0                  43               1         1              0
#
#      Motor vehicle theft  Arson
# 0                     15      0
# 4                    466     47
# 19                     1      0
# 22                     1      0
# 188                    0      0

# %% [markdown]
#     OJJDP provides data across multiple files, we'll save those to a dictionary of dataframes, and create a new dataframe with summary data (year over year for all-crime)

# %%
OJJDP_files = [FILE_PREFIX + str(year) + ".csv" for year in range(MIN_YEAR, MAX_YEAR+1)]

# dict where key is you path and value is dataframe    
all_df = {file: helper.create_df(DATA_PATH + file) for file in OJJDP_files}

# %% [markdown]
# # 3. Exploratory data analysis and preprocessing
#
# # Data Cleaning

# %%
# let's tidy up the data types and numberic representations for processing
# remove commas, since our values are all numerical representations
# replace any completely empty or entirely space values with NaN
# replace NaN with 0
# change to datatype float
fbi_fed_df = fbi_fed_df.replace('[,]', '', regex=True).replace(r'^\s*$', np.nan, regex=True).fillna(0).astype(float)

# # convert float values to integer
volume_columns = fbi_fed_df.columns[[2, 4, 8, 10, 12, 14, 16, 18, 20]]
fbi_fed_df[volume_columns] = fbi_fed_df[volume_columns].astype(int)

fbi_fed_df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19564/170929414.py in <module>
#       8 # # convert float values to integer
#       9 volume_columns = fbi_fed_df.columns[[2, 4, 8, 10, 12, 14, 16, 18, 20]]
# ---> 10 fbi_fed_df[volume_columns] = fbi_fed_df[volume_columns].astype(int)
#      11
#      12 fbi_fed_df.info()
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1093     if arr.ndim > 1:
#    1094         flat = arr.ravel()
# -> 1095         result = astype_nansafe(flat, dtype, copy=copy, skipna=skipna)
#    1096         # error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray]" has no
#    1097         # attribute "reshape"
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# ~\anaconda3\envs\dsfs\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '1,439,480'

# %%
# create column for all crime, place it first
fbi_fed_df.insert(loc=0, column='All offenses', value=fbi_fed_df['Violent\ncrime2'] + fbi_fed_df['Property \ncrime'])

fbi_fed_df.head()
# Out:
#           All offenses  Year  Population1 Violent\ncrime2  \
# 0  1,439,48010,437,189  2001  285,317,559       1,439,480
# 1  1,423,67710,455,277  2002  287,973,924       1,423,677
# 2  1,383,67610,442,862  2003  290,788,976       1,383,676
# 3  1,360,08810,319,386  2004  293,656,842       1,360,088
# 4  1,390,74510,174,754  2005  296,507,061       1,390,745
#
#    Violent \ncrime \nrate  Murder and\nnonnegligent \nmanslaughter  \
# 0                    504.5                                  16,037
# 1                    494.4                                  16,229
# 2                    475.8                                  16,528
# 3                    463.2                                  16,148
# 4                    469.0                                  16,740
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 0                                               5.6
# 1                                               5.6
# 2                                               5.7
# 3                                               5.5
# 4                                               5.6
#
#   Rape\n(revised \ndefinition)3  Rape\n(revised \ndefinition) \nrate3  \
# 0                           NaN                                   NaN
# 1                           NaN                                   NaN
# 2                           NaN                                   NaN
# 3                           NaN                                   NaN
# 4                           NaN                                   NaN
#
#   Rape\n(legacy \ndefinition)4  ...  Aggravated \nassault  \
# 0                       90,863  ...               909,023
# 1                       95,235  ...               891,407
# 2                       93,883  ...               859,030
# 3                       95,089  ...               847,381
# 4                       94,347  ...               862,220
#
#   Aggravated \nassault rate   Property \ncrime Property \ncrime \nrate   \
# 0                      318.6        10,437,189                 3,658.10
# 1                      309.5        10,455,277                 3,630.60
# 2                      295.4        10,442,862                 3,591.20
# 3                      288.6        10,319,386                 3,514.10
# 4                      290.8        10,174,754                 3,431.50
#
#     Burglary Burglary \nrate  Larceny-\ntheft Larceny-\ntheft rate   \
# 0  2,116,531            741.8       7,092,267              2,485.70
# 1  2,151,252            747.0       7,057,379              2,450.70
# 2  2,154,834            741.0       7,026,802              2,416.50
# 3  2,144,446            730.3       6,937,089              2,362.30
# 4  2,155,448            726.9       6,783,447              2,287.80
#
#    Motor \nvehicle \ntheft Motor \nvehicle \ntheft \nrate
# 0                1,228,391                           430.5
# 1                1,246,646                           432.9
# 2                1,261,226                           433.7
# 3                1,237,851                           421.5
# 4                1,235,859                           416.8
#
# [5 rows x 23 columns]

# %% [markdown]
#     For the OJJDP dataframes in our dictionary, we'll create a new dataframe combining years with crime stats for All ages only

# %%
years = [str(year) for year in range(MIN_YEAR, MAX_YEAR+1)]

OJJDP_all_ages = pd.DataFrame(columns=years, dtype = str)
OJJDP_all_ages.columns

# %% [markdown]
#     We can use any of the dataframes to get the "index" of the rows, i.e. the Crime Category, we'll insert this as first column

# %%
OJJDP_all_ages.insert(loc=0, column='Offenses', value=all_df['OJJDP_2009.csv']['Offenses'])

# %% [markdown]
#     Let's loop through each dataframe and add the column data to this dataframe, storing them as integer type

# %%
column = 'All ages'
i = 0

for year in range(MIN_YEAR, MAX_YEAR+1):
    key = OJJDP_files[i]
    OJJDP_all_ages[str(year)] = all_df[key][column].replace('[,]', '', regex=True).fillna('0').astype(int)
    i += 1

# %%
all_df['OJJDP_all_ages'] = OJJDP_all_ages

# %% [markdown]
#     Looking at the data we can remove the following rows, as they are not reported and no imputed values will be accurate:
#
#         Rape
#         Sex offenses (except rape & prostitution)
#         Violent Crime Index

# %%
all_df['OJJDP_all_ages'] = all_df['OJJDP_all_ages'].drop([2, 17, 28])

# %%
# slice dataframe to only first row (all crime)
all_offenses = all_df['OJJDP_all_ages'].loc[:0, str(MIN_YEAR):str(MAX_YEAR)]
all_offenses

# %% [markdown]
# # Data Exploration

# %%
OJJDP_labels = list(all_offenses.columns)
OJJDP_datapoints = all_offenses.loc[0]
helper.plot_barchart(OJJDP_labels, OJJDP_datapoints, 'OJJDP all-crime rate by year', trendline=True)

# %%
# create barchart using year from ODDJP chart, to compare
fbi_labels = list(fbi_fed_file['Year'].iloc[8:-2].astype(str))
fbi_datapoints = fbi_fed_file['All offenses'].iloc[8:-2]
helper.plot_barchart(fbi_labels, fbi_datapoints, 'FBI all-crime rate by year', trendline=True)

# %% [markdown]
#     We have created a figure representing the data by state (all crime)

# %%
mean = round(fbi_state_df['Violent crime'].mean(), 0)
std = round(fbi_state_df['Violent crime'].std(), 0)

# Generate data on commute times.
size, scale = 1000, 10

fbi_state_df['Violent crime'].plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')

plt.title('State Violent Crime Histogram')
plt.text(4050, 35, r'$\mu={mean}, b={std}$'.format(mean=mean, std=std))
plt.xlabel('Counts')
plt.ylabel('Incidents')
plt.grid(axis='y', alpha=0.75)

# %% [markdown]
#     Let's remove any values greater than 1 standard deviations from the mean

# %%
one_dev = fbi_state_df['Violent crime'].loc[(np.abs(stats.zscore(fbi_state_df['Violent crime'])) < 1)]

mean = round(one_dev.mean(), 0)
count = one_dev.count()

plt.text(205, 32, r'$\mu={mean}, n={count}$'.format(mean=mean, count=count))

one_dev.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
#     Let's create a numpy array of 52 rows and 10 columns. We create a numpy array of data points because the Scikit-Learn library can work with numpy array type data inputs without requiring any preprocessing.

# %%
# make a numpy array of all the numerical columns in the dataframe (all but the first, State)
X = fbi_state_df.iloc[:, 1:].to_numpy()

# %%
plt.scatter(X[:,0],X[:,5], label='True Position')

# %% [markdown]
# # 4. Creating and evaluating a machine learning model

# %%
kmeans = KMeans(n_clusters=7)
kmeans.fit(X)

# print the center of each dimension, per cluster
print(kmeans.cluster_centers_)

print(kmeans.labels_)

# %%
# plot the data points in rainbow colors
plt.scatter(X[:,0],X[:,5], c=kmeans.labels_, cmap='rainbow', marker='o')

# plot the centroids in black
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], color='black', marker='.')

# %% [markdown]
#        That's not very intuitive unfortunately, let's plot this against a map, with state colors denoted by cluster
#
#        source: https://www.kaggle.com/elliotwyman/crime-clusters-over-state-map/

# %%
Image(filename= DATA_PATH + 'state_clusters.png')
