# %% [markdown]
# # Steps in Creating a Data Science Project
#
# 1. Defining the problem
# **Business problem description:**
# **Technical problem description:**
#
# 2. Getting the data
# Setup environment
#     Import libraries
#     Define constants and control variables
#
# 3. Exploratory data analysis
#
# 4. Preparing the data for Machine Learning Algorithms
# Data cleaning
# Feature engineering
# preprocessing
#
# 5. Creating and evaluating multiple machine learning models
#
# 6. Tuning and selecting final models
#
# 7. Presenting findings and/or solutions
#
# 8. Launch, monitoring, and maintenance of system

# %% [markdown]
# # 1. Defining the problem
#
#     **Business problem description:**
#
#     **Technical problem description:**

# %% [markdown]
# # 2. Getting the data

# %% [markdown]
# # Setup environment

# %% [markdown]
#     # Import libraries

# %%
# library helper
# run: importnb-install from Conda before using
from importnb import Notebook
with Notebook(): 
    import Utility

# custom helper class (from jupyter notebook)
helper = Utility.Helper()

from bs4 import BeautifulSoup
import requests

import re

from string import ascii_lowercase

# progress bars for long running functions
import tqdm
# Out:
# Class 'Helper' v1.3 has been loaded

# %%
# reload changes in Jupyter notebooks
from importlib import reload
with Notebook(): __name__ == '__main__' and reload(Utility)

# %% [markdown]
#     # Define constants and control variables

# %%
DATA_PATH = '../../data/'

LYRICS_URL = 'https://www.lyrics.com/'

# %% [markdown]
#     Data for this project will be collected via Web Scraper using BeautifulSoup, with content taken from lyrics.com

# %% [markdown]
#     Grab the list of artists, by first letter or number, container looks like:
#
#         <div id ="content-body" class="row">
#         ...
#             <div class="tdata-ext">
#                 <table class="tdata">
#                 ...
#                     <tbody>
#                         <tr><td class="tal qx"><strong><a href="artist/A-Band-Called-David/788850">A Band Called David</a></strong></td><td class="tal qx">7</td><td class="tal qx"><a href="artist-fans/788850">2</a></td></tr>
#
#     therefore we can use the anchor tag <a> to grab both artist URL and name

# %%
pattern = re.compile("artist-fans")

artists_dict = {}

# wrap function in progress bar, len(alphabet) + 1
for char in tqdm.tqdm(ascii_lowercase):

    # providing an integer to the URL will force the page to display up to that number of artists
    artists_url = LYRICS_URL + "artists/" + char + "/99999"
    artists_html = requests.get(artists_url).text
    artists_soup = BeautifulSoup(artists_html, 'html5lib')

    artists_a = artists_soup.find('div', id='content-body').find('table', class_=re.compile("tdata")).find('tbody').find_all('a')

    # there are links to number of fans by artists, we'll filter these out
    temp_dict = {artists.text: artists.get("href") for artists in artists_a if not re.match(pattern, artists.get("href"))}

    # join dictionaries
    artists_dict = {**artists_dict, **temp_dict} 

# loop once more for artists starting with a number (all entries are stored at url 0)  
artists_url = LYRICS_URL + "artists/0/99999"
artists_html = requests.get(artist_url).text
artists_soup = BeautifulSoup(artist_html, 'html5lib')

artists_links = artists_soup.find('div', id='content-body').find('table', class_=re.compile("tdata")).find('tbody').find_all('a')

# there are links to number of fans by artists, we'll filter these out
temp_dict = {artists.text: artists.get("href") for artists in artists_a if not re.match(pattern, artists.get("href"))}

# join dictionaries
artists_dict = {**artists_dict, **temp_dict}
# Out:
#   File "C:\Users\ellio\AppData\Local\Temp/ipykernel_26372/4247979173.py", line 9
#     artist_url = LYRICS_URL + artists/" + char + "/99999"
#                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
artists_dict
# Out:
# {'A B': 'artist/A-B/472398',
#  'A Bad Think': 'artist/A-Bad-Think/2137849593',
#  'A Baffled Republic': 'artist/A-Baffled-Republic/2137849643',
#  'A Banca 021': 'artist/A-Banca-021/2137850524',
#  'A Band Called "O"': 'artist/A-Band-Called-%22O%22/19641',
#  'A Band Called David': 'artist/A-Band-Called-David/788850',
#  'A Band of Bees': 'artist/A-Band-of-Bees/526494',
#  'A Band of Bitches': 'artist/A-Band-of-Bitches/2715023',
#  'A Band Of Boys': 'artist/A-Band-Of-Boys/2137852109',
#  'A Banjo Frolic': 'artist/A-Banjo-Frolic/2216388',
#  'A Beautiful End': 'artist/A-Beautiful-End/2137855403',
#  'A Black and White Movie': 'artist/A-Black-and-White-Movie/2391959',
#  'A Blue Ocean Dream': 'artist/A-Blue-Ocean-Dream/706753',
#  'A Boogie': 'artist/A-Boogie/3411424',
#  'A Boogie wit da Hoodie': 'artist/A-Boogie-wit-da-Hoodie/3229023',
#  'A Boy': 'artist/A-Boy/1659681',
#  'A Boy and His Kite': 'artist/A-Boy-and-His-Kite/2714702',
#  'A Brazuca': 'artist/A-Brazuca/2137846875',
#  'A Breach of Silence': 'artist/A-Breach-of-Silence/2846851',
#  'A Burning Water': 'artist/A-Burning-Water/724720',
#  'A Camp': 'artist/A-Camp/510710',
#  'A Canorous Quintet': 'artist/A-Canorous-Quintet/556338',
#  'A Cappella Plus': 'artist/A-Cappella-Plus/3293199',
#  'A Certain Ratio': 'artist/A-Certain-Ratio/16365',
#  'A Change of Pace': 'artist/A-Change-of-Pace/695678',
#  'A Chicken': 'artist/A-Chicken/1815854',
#  'A Chinese Firedrill': 'artist/A-Chinese-Firedrill/925054',
#  'A Chorus Line Cast Ensemble': 'artist/A-Chorus-Line-Cast-Ensemble/1376839',
#  'A Chorus Line Company': 'artist/A-Chorus-Line-Company/1860665',
#  'A Consommer de Préférence': 'artist/A-Consommer-de-Pr%C3%A9f%C3%A9rence/1009225',
#  'A Cor Do Som': 'artist/A-Cor-Do-Som/442548',
#  'A Covenant of Thorns': 'artist/A-Covenant-of-Thorns/2137855997',
#  'A Crazy Sound Convoy': 'artist/A-Crazy-Sound-Convoy/1177396',
#  'a crowd of rebellion': 'artist/a-crowd-of-rebellion/3212815',
#  'A Cursive Memory': 'artist/A-Cursive-Memory/817137',
#  'A Dam-Shame': 'artist/A-Dam-Shame/584644',
#  'A Dama': 'artist/A-Dama/2137853809',
#  'A Dark Halo': 'artist/A-Dark-Halo/848652',
#  'A Davey': 'artist/A-Davey/787025',
#  'A Day in Black and White': 'artist/A-Day-in-Black-and-White/655964',
#  'A Day in the Life': 'artist/A-Day-in-the-Life/702933',
#  'A Day of Pigs': 'artist/A-Day-of-Pigs/1007720',
#  'A Day to Remember': 'artist/A-Day-to-Remember/702646',
#  'A Dead Giveaway': 'artist/A-Dead-Giveaway/709117',
#  'A Death for Every Sin': 'artist/A-Death-for-Every-Sin/529735',
#  'A Do': 'artist/A-Do/975737',
#  'A Dozen Furies': 'artist/A-Dozen-Furies/735570',
#  'A Drop in the Gray': 'artist/A-Drop-in-the-Gray/38496',
#  'A Dying Dream': 'artist/A-Dying-Dream/800626',
#  'A Faith Called Chaos': 'artist/A-Faith-Called-Chaos/657462',
#  'A Fall Farewell': 'artist/A-Fall-Farewell/744924',
#  'A Few Good Men': 'artist/A-Few-Good-Men/50078',
#  'A Filetta': 'artist/A-Filetta/341398',
#  'A Fine Frenzy': 'artist/A-Fine-Frenzy/860401',
#  'A Firm Handshake': 'artist/A-Firm-Handshake/2825605',
#  'A Flock of Seagulls': 'artist/A-Flock-of-Seagulls/4280',
#  'A Foot in Coldwater': 'artist/A-Foot-in-Coldwater/17616',
#  'A Forest of Stars': 'artist/A-Forest-of-Stars/1115839',
#  'A Frames': 'artist/A-Frames/695336',
#  'A Friend in London': 'artist/A-Friend-in-London/2391439',
#  'A Fúria do Açúcar': 'artist/A-F%C3%BAria-do-A%C3%A7%C3%BAcar/2137851342',
#  'A Gift of Love': 'artist/A-Gift-of-Love/401565',
#  'A Girl A Gun A Ghost': 'artist/A-Girl-A-Gun-A-Ghost/1027106',
#  'A Girl Called Eddy': 'artist/A-Girl-Called-Eddy/484115',
#  'A Global Threat': 'artist/A-Global-Threat/435631',
#  'A Great Big World': 'artist/A-Great-Big-World/2803870',
#  'A Guy Called Gerald': 'artist/A-Guy-Called-Gerald/12122',
#  'A Hard Mountain': 'artist/A-Hard-Mountain/1178257',
#  'A Hawk and a Hacksaw': 'artist/A-Hawk-and-a-Hacksaw/666747',
#  'A Heartwell Ending': 'artist/A-Heartwell-Ending/787506',
#  'A Hero from a Thousand Paces': 'artist/A-Hero-from-a-Thousand-Paces/890087',
#  "A Hero's Fate": 'artist/A-Hero%27s-Fate/2068932',
#  'a home video': 'artist/a-home-video/2137860569',
#  'A House': 'artist/A-House/12123',
#  'A Jealousy Issue': 'artist/A-Jealousy-Issue/609829',
#  'A Kiss Could Be Deadly': 'artist/A-Kiss-Could-Be-Deadly/1021619',
#  'A la Carte': 'artist/A-la-Carte/15245',
#  'A la Carte Brass & Percussion': 'artist/A-la-Carte-Brass-%26-Percussion/203941',
#  'A Lanky Swede': 'artist/A-Lanky-Swede/2759181',
#  'A Lex': 'artist/A-Lex/454569',
#  'A Life Divided': 'artist/A-Life-Divided/1020968',
#  'A Life Once Lost': 'artist/A-Life-Once-Lost/555198',
#  'A Little Space': 'artist/A-Little-Space/531673',
#  'A Long Winter': 'artist/A-Long-Winter/543920',
#  'A Lot Like Birds': 'artist/A-Lot-Like-Birds/2484310',
#  'A Love Like Pi': 'artist/A-Love-Like-Pi/2137848459',
#  'A Low Watt Document': 'artist/A-Low-Watt-Document/1890304',
#  'A M': 'artist/A-M/1040971',
#  'A Man Called Adam': 'artist/A-Man-Called-Adam/50079',
#  'A Melodic Daydream': 'artist/A-Melodic-Daydream/715971',
#  'A Million Different People': 'artist/A-Million-Different-People/2904938',
#  'A Miss': 'artist/A-Miss/856837',
#  'A Mist of Gentle Rain': 'artist/A-Mist-of-Gentle-Rain/2258508',
#  'A New Ascension': 'artist/A-New-Ascension/1132632',
#  'A New January': 'artist/A-New-January/553245',
#  'A O C': 'artist/A-O-C/2137856699',
#  'A one': 'artist/A-one/2137854713',
#  'A Pale Horse Named Death': 'artist/A-Pale-Horse-Named-Death/2137849087',
#  'A Penguin': 'artist/A-Penguin/1658558',
#  'A Perfect Circle': 'artist/A-Perfect-Circle/430677',
#  'A Perfect Murder': 'artist/A-Perfect-Murder/559629',
#  'A Phoenix Forever': 'artist/A-Phoenix-Forever/1186133',
#  'A Place to Bury Strangers': 'artist/A-Place-to-Bury-Strangers/850988',
#  'A Prophet Among Us': 'artist/A-Prophet-Among-Us/2137848945',
#  'A R I Z O N A': 'artist/A-R-I-Z-O-N-A/3148345',
#  'A Radio With Guts': 'artist/A-Radio-With-Guts/532149',
#  'A Ragamuffin Band': 'artist/A-Ragamuffin-Band/404088',
#  'A Rocket to the Moon': 'artist/A-Rocket-to-the-Moon/1096307',
#  'A Secret Sense': 'artist/A-Secret-Sense/1096198',
#  'A Silent Film': 'artist/A-Silent-Film/958523',
#  'A Silver Mt. Zion': 'artist/A-Silver-Mt.-Zion/419583',
#  'A Skylit Drive': 'artist/A-Skylit-Drive/864070',
#  'A Small Victory': 'artist/A-Small-Victory/606520',
#  'A Split Second': 'artist/A-Split-Second/12127',
#  'A Static Lullaby': 'artist/A-Static-Lullaby/553364',
#  'A Step Behind': 'artist/A-Step-Behind/721243',
#  'A Taste of Honey': 'artist/A-Taste-of-Honey/50080',
#  'A Taste of Ra': 'artist/A-Taste-of-Ra/726360',
#  'A Thorn for Every Heart': 'artist/A-Thorn-for-Every-Heart/679883',
#  'A Thousand Horses': 'artist/A-Thousand-Horses/2237392',
#  'A Thousand Years': 'artist/A-Thousand-Years/722100',
#  'A Three Thousand': 'artist/A-Three-Thousand/210695',
#  'A Touch of Charm': 'artist/A-Touch-of-Charm/722318',
#  'A Touch of Class': 'artist/A-Touch-of-Class/193420',
#  'A Tribe Called Quest': 'artist/A-Tribe-Called-Quest/50081',
#  'A Tribe Called Red': 'artist/A-Tribe-Called-Red/2620448',
#  'A Tribute to Simple Minds': 'artist/A-Tribute-to-Simple-Minds/722421',
#  'A Turma do Cocoricó': 'artist/A-Turma-do-Cocoric%C3%B3/2137848178',
#  'A Turma do Seu Lobato': 'artist/A-Turma-do-Seu-Lobato/2137848236',
#  'A Voice Like Rhetoric': 'artist/A-Voice-Like-Rhetoric/925087',
#  'A Weather': 'artist/A-Weather/1034311',
#  'A Whisper in the Noise': 'artist/A-Whisper-in-the-Noise/723445',
#  'A Wilhelm Scream': 'artist/A-Wilhelm-Scream/645403',
#  'A$Ap Ant': 'artist/A%24Ap-Ant/3429225',
#  'A$AP Ferg': 'artist/A%24AP-Ferg/2746329',
#  'A$AP Mob': 'artist/A%24AP-Mob/2878396',
#  'A$AP Nast': 'artist/A%24AP-Nast/3036007',
#  'A$AP Rocky': 'artist/A%24AP-Rocky/2475562',
#  'A$Ap Twelvyy': 'artist/A%24Ap-Twelvyy/2651665',
#  'A$AP Yams': 'artist/A%24AP-Yams/3103782',
#  'A$Ton Matthews': 'artist/A%24Ton-Matthews/3116627',
#  'A$ton Wyld': 'artist/A%24ton-Wyld/2137856823',
#  "A' Eye": 'artist/A%26%23039%3B-Eye/893801',
#  'A&B Creative Duo': 'artist/A%26B-Creative-Duo/2699501',
#  "A'ba-Cus": 'artist/A%27ba-Cus/296892',
#  "A'doni": 'artist/A%27doni/3479004',
#  "A'Leithia Sweeting": 'artist/A%27Leithia-Sweeting/2137844925',
#  "A'me Lorain": 'artist/A%27me-Lorain/13533',
#  "A'nt Idy Harper": 'artist/A%27nt-Idy-Harper/153516',
#  "A'Sa": 'artist/A%27Sa/359918',
#  'A*M*E': 'artist/A%2AM%2AE/2755254',
#  'A*Star': 'artist/A%2AStar/792104',
#  'A*Teens': 'artist/A%2ATeens/2663185',
#  'A+': 'artist/A%2B/50083',
#  'A-1': 'artist/A-1/375987',
#  'A-3': 'artist/A-3/925093',
#  'A-Alikes': 'artist/A-Alikes/757864',
#  'A-Bless': 'artist/A-Bless/743446',
#  'A-Chief': 'artist/A-Chief/478090',
#  'A-Cyde': 'artist/A-Cyde/1815817',
#  'A-D': 'artist/A-D/485549',
#  'A-Dam-Shame': 'artist/A-Dam-Shame/1658808',
#  'A-Deal': 'artist/A-Deal/2137853656',
#  'A-F-R-O AKA All Flows Reach Out': 'artist/A-F-R-O-AKA-All-Flows-Reach-Out/3106289',
#  'A-G-2-A-KE': 'artist/A-G-2-A-KE/310048',
#  'A-Gee': 'artist/A-Gee/375755',
#  'a-ha': 'artist/a-ha/3491',
#  'A-Kon': 'artist/A-Kon/289847',
#  'A-La-Soul': 'artist/A-La-Soul/2825352',
#  'A-Live': 'artist/A-Live/748562',
#  'A-One': 'artist/A-One/182946',
#  'A-One & Bo': 'artist/A-One-%26-Bo/1024083',
#  'A-P': 'artist/A-P/1037559',
#  'A-Plus': 'artist/A-Plus/2144543',
#  'A-Ram': 'artist/A-Ram/2137856929',
#  'A-Reece': 'artist/A-Reece/2137850673',
#  'A-Studio': 'artist/A-Studio/787957',
#  'A-Team': 'artist/A-Team/1658647',
#  'A-Tech': 'artist/A-Tech/2582620',
#  'A-Tom': 'artist/A-Tom/2137857249',
#  'A-Track': 'artist/A-Track/2271710',
#  'A-Trak': 'artist/A-Trak/396069',
#  'A-Vox': 'artist/A-Vox/3294064',
#  'A-Wall': 'artist/A-Wall/2137858950',
#  'A-Wax': 'artist/A-Wax/516088',
#  'A. Algara': 'artist/A.-Algara/1658645',
#  'A. Carter': 'artist/A.-Carter/340341',
#  'A. Domínguez': 'artist/A.-Dom%C3%ADnguez/341069',
#  'A. Droid': 'artist/A.-Droid/2074083',
#  'A. Fischer': 'artist/A.-Fischer/341407',
#  'A. G. Cook': 'artist/A.-G.-Cook/2137850386',
#  'A. Human': 'artist/A.-Human/1058241',
#  'A. Igman': 'artist/A.-Igman/43375',
#  'A. J. Melendez': 'artist/A.-J.-Melendez/597347',
#  'A. Lasry': 'artist/A.-Lasry/785237',
#  'A. Moore': 'artist/A.-Moore/343688',
#  'A. Nash': 'artist/A.-Nash/1812265',
#  'A. Odén': 'artist/A.-Od%C3%A9n/2584597',
#  'A. Pernilla': 'artist/A.-Pernilla/798534',
#  'A. Ray Fuller': 'artist/A.-Ray-Fuller/78181',
#  'A. Skillz & Krafty Kuts': 'artist/A.-Skillz-%26-Krafty-Kuts/662012',
#  'A. Turner': 'artist/A.-Turner/381460',
#  'A.18': 'artist/A.18/554749',
#  'A.A. Bondy': 'artist/A.A.-Bondy/923063',
#  'A.A.V.V.': 'artist/A.A.V.V./1003481',
#  'A.B. Quintanilla III': 'artist/A.B.-Quintanilla-III/365890',
#  'A.B. Quintanilla y los Kumbia Kings': 'artist/A.B.-Quintanilla-y-los-Kumbia-Kings/547001',
#  'A.B.K. International': 'artist/A.B.K.-International/454417',
#  'A.B.S. Orchestra': 'artist/A.B.S.-Orchestra/2080923',
#  'A.C.': 'artist/A.C./200312',
#  'A.C. Newman': 'artist/A.C.-Newman/657815',
#  'A.C. Reed': 'artist/A.C.-Reed/503',
#  'A.C.D.': 'artist/A.C.D./1013419',
#  'A.C.E': 'artist/A.C.E/3363380',
#  'A.C.K.': 'artist/A.C.K./1003482',
#  'A.C.O': 'artist/A.C.O/2137854105',
#  'A.C.T.': 'artist/A.C.T./511896',
#  'A.CHAL': 'artist/A.CHAL/2733492',
#  'A.D. Scott': 'artist/A.D.-Scott/3228004',
#  'A.D.A.M.': 'artist/A.D.A.M./216001',
#  'A.D.O.R.': 'artist/A.D.O.R./201361',
#  'A.F.O. Studio Combo': 'artist/A.F.O.-Studio-Combo/1086221',
#  'A.G.': 'artist/A.G./987786',
#  'A.G. Cook': 'artist/A.G.-Cook/2137849383',
#  'A.G. Trio': 'artist/A.G.-Trio/1182778',
#  'A.G.A.M.A': 'artist/A.G.A.M.A/2738499',
#  'A.I.': 'artist/A.I./1656626',
#  'A.J Dean': 'artist/A.J-Dean/2580618',
#  'A.J.': 'artist/A.J./396084',
#  'A.J. & Company': 'artist/A.J.-%26-Company/430109',
#  'A.J. Croce': 'artist/A.J.-Croce/38126',
#  'A.J. DeBravo': 'artist/A.J.-DeBravo/515139',
#  'A.J. McLean': 'artist/A.J.-McLean/302579',
#  'A.J. Rosales': 'artist/A.J.-Rosales/719369',
#  'A.J. Teshin': 'artist/A.J.-Teshin/1072404',
#  'A.K.': 'artist/A.K./310240',
#  'A.K. Paul': 'artist/A.K.-Paul/3026358',
#  'A.K.P.': 'artist/A.K.P./289856',
#  'A.L.': 'artist/A.L./1657651',
#  'A.L. Jinwright': 'artist/A.L.-Jinwright/1812990',
#  'A.L. Lloyd': 'artist/A.L.-Lloyd/144235',
#  'A.L.G.': 'artist/A.L.G./374630',
#  'A.L.T.': 'artist/A.L.T./385027',
#  'A.L.T. Saint': 'artist/A.L.T.-Saint/471998',
#  'A.M. Matrosenchor': 'artist/A.M.-Matrosenchor/980224',
#  'A.M. Sixty': 'artist/A.M.-Sixty/2137856614',
#  'A.M.M.O.': 'artist/A.M.M.O./558282',
#  'A.M.P.': 'artist/A.M.P./1108325',
#  'A.M.R.': 'artist/A.M.R./1120556',
#  'A.M.X.': 'artist/A.M.X./2520539',
#  'A.N.I.M.A.L.': 'artist/A.N.I.M.A.L./52058',
#  'A.O.S.': 'artist/A.O.S./175072',
#  'A.P.': 'artist/A.P./924393',
#  'A.P. Carter': 'artist/A.P.-Carter/62814',
#  'A.R. Kane': 'artist/A.R.-Kane/3489',
#  'A.R. Rahman': 'artist/A.R.-Rahman/278580',
#  'A.R.P': 'artist/A.R.P/2339967',
#  'A.S.A.P.': 'artist/A.S.A.P./12126',
#  'A.S.K. M.E': 'artist/A.S.K.-M.E/1037077',
#  'A.S.K. M.E. & Vic Black': 'artist/A.S.K.-M.E.-%26-Vic-Black/1657989',
#  'A.Tihovsky': 'artist/A.Tihovsky/2619313',
#  'A.V.': 'artist/A.V./800244',
#  'A.V.B.': 'artist/A.V.B./37166',
#  'A.W.B.': 'artist/A.W.B./485598',
#  'A1': 'artist/A1/403335',
#  'A1 People': 'artist/A1-People/362695',
#  'A1 x J1 ': 'artist/A1-x-J1-/2137854663',
#  'A2': 'artist/A2/298779',
#  'A2H': 'artist/A2H/2137852845',
#  'A2l': 'artist/A2l/363409',
#  'A2P': 'artist/A2P/2212536',
#  'A3': 'artist/A3/276222',
#  'A36': 'artist/A36/2137859934',
#  'A7S': 'artist/A7S/3511640',
#  'A:xus': 'artist/A%3Axus/353723',
#  'AAA': 'artist/AAA/372703',
#  'Aacacia': 'artist/Aacacia/2137850280',
#  'Aad Mouthaan': 'artist/Aad-Mouthaan/2390113',
#  'Aadesh Shrivastava': 'artist/Aadesh-Shrivastava/794913',
#  'Aafje Van Summeren': 'artist/Aafje-Van-Summeren/795191',
#  'Aage Tanggaard': 'artist/Aage-Tanggaard/130366',
#  'Aalias': 'artist/Aalias/2890967',
#  'Aaliyah': 'artist/Aaliyah/44722',
#  'Aamir Khan': 'artist/Aamir-Khan/1061413',
#  'Aanysa': 'artist/Aanysa/3290344',
#  'Aaradhna': 'artist/Aaradhna/821214',
#  'Aarc Mass Choir': 'artist/Aarc-Mass-Choir/524319',
#  'Aardvark Kids Music': 'artist/Aardvark-Kids-Music/2178145',
#  'AAries': 'artist/AAries/535485',
#  'AaRON': 'artist/AaRON/886636',
#  'Aaron': 'artist/Aaron/1055715',
#  'Aaron & Damion Hall': 'artist/Aaron-%26-Damion-Hall/1810705',
#  'Aaron & Jeoffrey': 'artist/Aaron-%26-Jeoffrey/141709',
#  'Aaron Alexander': 'artist/Aaron-Alexander/146986',
#  'Aaron Bell': 'artist/Aaron-Bell/8056',
#  'Aaron Bereal': 'artist/Aaron-Bereal/3426197',
#  'Aaron Binder': 'artist/Aaron-Binder/278531',
#  'Aaron Bruno': 'artist/Aaron-Bruno/340106',
#  'Aaron Burdett': 'artist/Aaron-Burdett/898442',
#  'Aaron Carpenter': 'artist/Aaron-Carpenter/2137846951',
#  'Aaron Carter': 'artist/Aaron-Carter/294384',
#  'Aaron Caruso': 'artist/Aaron-Caruso/925143',
#  'Aaron Choulai': 'artist/Aaron-Choulai/655806',
#  'Aaron Choulai Trio': 'artist/Aaron-Choulai-Trio/1561320',
#  'Aaron Cole': 'artist/Aaron-Cole/572385',
#  'Aaron Curtis': 'artist/Aaron-Curtis/1133109',
#  'Aaron Davis': 'artist/Aaron-Davis/69014',
#  'Aaron Delossantos': 'artist/Aaron-Delossantos/847596',
#  'Aaron Dessner': 'artist/Aaron-Dessner/582854',
#  'Aaron Diehl': 'artist/Aaron-Diehl/1141953',
#  'Aaron Doyle': 'artist/Aaron-Doyle/341103',
#  'Aaron Drako': 'artist/Aaron-Drako/2403180',
#  'Aaron Emanuel': 'artist/Aaron-Emanuel/3080754',
#  'Aaron Embry': 'artist/Aaron-Embry/574864',
#  'Aaron Espe': 'artist/Aaron-Espe/893474',
#  'Aaron Frazer': 'artist/Aaron-Frazer/2137851101',
#  'Aaron Fresh': 'artist/Aaron-Fresh/2171999',
#  'Aaron Gibson': 'artist/Aaron-Gibson/79817',
#  'Aaron Gillespie': 'artist/Aaron-Gillespie/526528',
#  'Aaron Goldberg': 'artist/Aaron-Goldberg/293534',
#  'Aaron Goodvin': 'artist/Aaron-Goodvin/2689862',
#  'Aaron Gordon': 'artist/Aaron-Gordon/538090',
#  'Aaron Hall': 'artist/Aaron-Hall/39267',
#  'Aaron Immanuel Wright': 'artist/Aaron-Immanuel-Wright/2073136',
#  'Aaron James': 'artist/Aaron-James/393463',
#  'Aaron Jeoffrey': 'artist/Aaron-Jeoffrey/1808845',
#  'Aaron Jerome': 'artist/Aaron-Jerome/2137859453',
#  'Aaron K. Gray': 'artist/Aaron-K.-Gray/511406',
#  'Aaron Kamin': 'artist/Aaron-Kamin/550990',
#  'Aaron LaCrate': 'artist/Aaron-LaCrate/842300',
#  'Aaron Lewis': 'artist/Aaron-Lewis/189097',
#  'Aaron Lindsey': 'artist/Aaron-Lindsey/98645',
#  'Aaron Lines': 'artist/Aaron-Lines/541629',
#  'Aaron Livingston': 'artist/Aaron-Livingston/987870',
#  'Aaron Lohr': 'artist/Aaron-Lohr/99184',
#  'Aaron Lovac': 'artist/Aaron-Lovac/3455329',
#  'Aaron Mansfield': 'artist/Aaron-Mansfield/2137856930',
#  'Aaron Marsh': 'artist/Aaron-Marsh/759143',
#  'Aaron McDaris': 'artist/Aaron-McDaris/551234',
#  'Aaron Meyer': 'artist/Aaron-Meyer/450007',
#  'Aaron Modesto': 'artist/Aaron-Modesto/3571142',
#  'Aaron Nesby': 'artist/Aaron-Nesby/546830',
#  'Aaron Neville': 'artist/Aaron-Neville/5008',
#  'Aaron Pritchett': 'artist/Aaron-Pritchett/747183',
#  'Aaron Ramsey': 'artist/Aaron-Ramsey/814640',
#  'Aaron Rose': 'artist/Aaron-Rose/893488',
#  'Aaron Sachs': 'artist/Aaron-Sachs/9585',
#  'Aaron Shaw': 'artist/Aaron-Shaw/3089992',
#  'Aaron Shust': 'artist/Aaron-Shust/735876',
#  'Aaron Skyy': 'artist/Aaron-Skyy/371907',
#  'Aaron Smith': 'artist/Aaron-Smith/126163',
#  'Aaron Sokell': 'artist/Aaron-Sokell/383871',
#  'Aaron Spiro': 'artist/Aaron-Spiro/533722',
#  'Aaron Springfield': 'artist/Aaron-Springfield/466079',
#  'Aaron Sprinkle': 'artist/Aaron-Sprinkle/180963',
#  'Aaron Staccato': 'artist/Aaron-Staccato/2137855812',
#  'Aaron Tesser & The New Jazz Affair': 'artist/Aaron-Tesser-%26-The-New-Jazz-Affair/1600279',
#  'Aaron Thomas': 'artist/Aaron-Thomas/893490',
#  'Aaron Tippin': 'artist/Aaron-Tippin/1842',
#  'Aaron Tveit': 'artist/Aaron-Tveit/1184113',
#  'Aaron Tviet': 'artist/Aaron-Tviet/2743900',
#  'Aaron Watson': 'artist/Aaron-Watson/532698',
#  'Aaron Weinstein': 'artist/Aaron-Weinstein/618325',
#  'Aaron West & the Roaring Twenties': 'artist/Aaron-West-%26-the-Roaring-Twenties/2137845379',
#  'Aaron West and the Roaring Twenties': 'artist/Aaron-West-and-the-Roaring-Twenties/2971109',
#  'Aarón Y Su Grupo Ilusión': 'artist/Aar%C3%B3n-Y-Su-Grupo-Ilusi%C3%B3n/207790',
#  'Aaron Zigman': 'artist/Aaron-Zigman/140972',
#  'Aarpa': 'artist/Aarpa/3514393',
#  'Aaryn Doyle': 'artist/Aaryn-Doyle/1068918',
#  'Aave': 'artist/Aave/3103831',
#  'Aazar': 'artist/Aazar/3295677',
#  'AB': 'artist/AB/1110259',
#  'AB Crazy': 'artist/AB-Crazy/2137850811',
#  'AB De Villiers': 'artist/AB-De-Villiers/2137850752',
#  'AB Ivens': 'artist/AB-Ivens/562171',
#  'Ab Liva': 'artist/Ab-Liva/922899',
#  'AB Logic': 'artist/AB-Logic/21633',
#  'AB Luva': 'artist/AB-Luva/478822',
#  'Ab Schaap': 'artist/Ab-Schaap/122456',
#  'Ab-Liva': 'artist/Ab-Liva/1656965',
#  'Ab-Soul': 'artist/Ab-Soul/1168200',
#  'AB6IX': 'artist/AB6IX/3537624',
#  'Aba Shante': 'artist/Aba-Shante/480012',
#  'Abacabb': 'artist/Abacabb/1108407',
#  'Abaddon': 'artist/Abaddon/2137856987',
#  'Abade Al Johar': 'artist/Abade-Al-Johar/979163',
#  'Abandon': 'artist/Abandon/698570',
#  'Abandon All Hope': 'artist/Abandon-All-Hope/1074586',
#  'Abandon All Ships': 'artist/Abandon-All-Ships/2229989',
#  'Abandon Jalopy': 'artist/Abandon-Jalopy/485154',
#  'Abandoned': 'artist/Abandoned/2563616',
#  'Abandoned by Bears': 'artist/Abandoned-by-Bears/3199738',
#  'Abandoned Pools': 'artist/Abandoned-Pools/510401',
#  'Abash': 'artist/Abash/512817',
#  'Abathakathi': 'artist/Abathakathi/2137851360',
#  'Abati': 'artist/Abati/2464569',
#  'Abattoir': 'artist/Abattoir/424281',
#  'ABBA': 'artist/ABBA/3492',
#  'Abba Dance': 'artist/Abba-Dance/558428',
#  'Abba DJ': 'artist/Abba-DJ/612090',
#  'Abba-DJ': 'artist/Abba-DJ/1826921',
#  'Abbacadabra': 'artist/Abbacadabra/2137856016',
#  'Abbamania': 'artist/Abbamania/1911550',
#  'Abbas Mehrpouya': 'artist/Abbas-Mehrpouya/2543793',
#  'Abbatoir': 'artist/Abbatoir/15254',
#  'Abbe Lane': 'artist/Abbe-Lane/342871',
#  'Abbey Lincoln': 'artist/Abbey-Lincoln/50151',
#  'Abbey Road Ensemble': 'artist/Abbey-Road-Ensemble/485733',
#  'Abbey Smith': 'artist/Abbey-Smith/3384702',
#  'Abbie Gardner': 'artist/Abbie-Gardner/430597',
#  'Abbittibbi': 'artist/Abbittibbi/2193471',
#  'Abbot Kinney Lighthouse Choir': 'artist/Abbot-Kinney-Lighthouse-Choir/1811622',
#  'Abbott Bruce': 'artist/Abbott-Bruce/633601',
#  'Abby Burke': 'artist/Abby-Burke/701923',
#  'Abby Dobson': 'artist/Abby-Dobson/752931',
#  'Abby Mallard': 'artist/Abby-Mallard/746366',
#  'Abby Parks': 'artist/Abby-Parks/893507',
#  'Abby Souya': 'artist/Abby-Souya/346859',
#  'Abby Travis': 'artist/Abby-Travis/303148',
#  'Abby Valdez': 'artist/Abby-Valdez/2137852344',
#  'ABC': 'artist/ABC/3494',
#  'Abcdefiend?': 'artist/Abcdefiend%3F/1088484',
#  'Abd Al Malik': 'artist/Abd-Al-Malik/821228',
#  'Abd El Halim Hafez': 'artist/Abd-El-Halim-Hafez/2137854576',
#  'Abdallah Al Rowaishid': 'artist/Abdallah-Al-Rowaishid/788869',
#  'Abdel Halim Hafez': 'artist/Abdel-Halim-Hafez/29635',
#  'Abdel Kabirr': 'artist/Abdel-Kabirr/39753',
#  'Abdel Wright': 'artist/Abdel-Wright/730316',
#  'Abdelfattah Grini': 'artist/Abdelfattah-Grini/2729409',
#  'Abdi': 'artist/Abdi/2916103',
#  'Abdiel ': 'artist/Abdiel-/2137852894',
#  "Abdou M'Boup": 'artist/Abdou-M%27Boup/100247',
#  'Abdu Ali': 'artist/Abdu-Ali/2137851066',
#  'Abdul': 'artist/Abdul/3419046',
#  'Abdul & The Coffee Theory': 'artist/Abdul-%26-The-Coffee-Theory/2137850713',
#  'Abdul Majeed Abdullah': 'artist/Abdul-Majeed-Abdullah/2137847320',
#  'Abdul Malik Ahmad': 'artist/Abdul-Malik-Ahmad/883468',
#  'Abdul Raheen': 'artist/Abdul-Raheen/370429',
#  'Abdul Rahman Al Huraibi': 'artist/Abdul-Rahman-Al-Huraibi/2137858266',
#  'Abdullah': 'artist/Abdullah/459842',
#  'Abdullah Ibrahim': 'artist/Abdullah-Ibrahim/89057',
#  'Abe': 'artist/Abe/818490',
#  'Abe Aaron': 'artist/Abe-Aaron/182714',
#  'Abe Dinovitch': 'artist/Abe-Dinovitch/166441',
#  'Abe Duque': 'artist/Abe-Duque/240012',
#  'Abe Ellstein Orchestra': 'artist/Abe-Ellstein-Orchestra/1656868',
#  'Abe Laboriel, Jr.': 'artist/Abe-Laboriel%2C-Jr./442994',
#  'Abe Lyman': 'artist/Abe-Lyman/11084',
#  'Abe Most': 'artist/Abe-Most/9259',
#  'Abe Silverman': 'artist/Abe-Silverman/860838',
#  'Abe Silverman Big Band': 'artist/Abe-Silverman-Big-Band/2344469',
#  'Abe Speller': 'artist/Abe-Speller/127342',
#  'Abe Vigoda': 'artist/Abe-Vigoda/925181',
#  "Abe's Logic": 'artist/Abe%27s-Logic/1158812',
#  'Abecedarians': 'artist/Abecedarians/12131',
#  'Abed Azrié': 'artist/Abed-Azri%C3%A9/29625',
#  'Abedi': 'artist/Abedi/975756',
#  'Abégé': 'artist/Ab%C3%A9g%C3%A9/893516',
#  'Abel': 'artist/Abel/921711',
#  'Abel Ames': 'artist/Abel-Ames/548424',
#  'Abel De Jong': 'artist/Abel-De-Jong/2137849476',
#  'Abel Flores': 'artist/Abel-Flores/2180268',
#  'Abel Korzeniowski': 'artist/Abel-Korzeniowski/714220',
#  'Abel Pintos': 'artist/Abel-Pintos/483508',
#  'Abel Romez': 'artist/Abel-Romez/2137858149',
#  'Abel Tesfaye': 'artist/Abel-Tesfaye/2695416',
#  'Abel Xanders': 'artist/Abel-Xanders/2137855406',
#  'Abel Zarate': 'artist/Abel-Zarate/181935',
#  'Abelardo Carbonó': 'artist/Abelardo-Carbon%C3%B3/2137853343',
#  'Abenaa': 'artist/Abenaa/485917',
#  'Abeng': 'artist/Abeng/142419',
#  'Abercrombie': 'artist/Abercrombie/509319',
#  'Aberdeen City': 'artist/Aberdeen-City/654695',
#  'Aberfeldy': 'artist/Aberfeldy/670278',
#  'Abeyance': 'artist/Abeyance/737527',
#  'Abhi Dijon': 'artist/Abhi-Dijon/3255834',
#  'Abhi the Nomad': 'artist/Abhi-the-Nomad/2137852804',
#  'Abhi//Dijon': 'artist/Abhi--Dijon/3189478',
#  'Abhijeet': 'artist/Abhijeet/555765',
#  'Abhijeet Bhattacharya': 'artist/Abhijeet-Bhattacharya/2137859123',
#  'Abhijeet Sawant': 'artist/Abhijeet-Sawant/2137859561',
#  'Abhir Hathi': 'artist/Abhir-Hathi/2137853234',
#  'Abhishek Bachchan': 'artist/Abhishek-Bachchan/991865',
#  'Abhorrance': 'artist/Abhorrance/705061',
#  'Abhorrent': 'artist/Abhorrent/477995',
#  'ABI': 'artist/ABI/1811178',
#  'Abi Tapia': 'artist/Abi-Tapia/721794',
#  'Abida Green': 'artist/Abida-Green/2527711',
#  'Abigail': 'artist/Abigail/2947287',
#  'Abigail Bailey': 'artist/Abigail-Bailey/681133',
#  'Abigail Barlow': 'artist/Abigail-Barlow/2137859587',
#  'Abigail Breslin': 'artist/Abigail-Breslin/2471218',
#  'Abigail Grush': 'artist/Abigail-Grush/380373',
#  'Abigail Johnson': 'artist/Abigail-Johnson/2935895',
#  'Abigail Payne': 'artist/Abigail-Payne/893531',
#  'Abigail Riccards': 'artist/Abigail-Riccards/1003389',
#  'Abigail Washburn': 'artist/Abigail-Washburn/681381',
#  'Abigail Wyles': 'artist/Abigail-Wyles/2535560',
#  "Abigail's Mercy": 'artist/Abigail%27s-Mercy/748842',
#  'Abigor': 'artist/Abigor/409038',
#  'Abingdon Boys School': 'artist/Abingdon-Boys-School/913609',
#  'Abir': 'artist/Abir/3111552',
#  'Abir Haronni': 'artist/Abir-Haronni/3058001',
#  'ABK': 'artist/ABK/673316',
#  'Ablaze My Sorrow': 'artist/Ablaze-My-Sorrow/640693',
#  'Able Baker Fox': 'artist/Able-Baker-Fox/1015935',
#  'ABN': 'artist/ABN/917970',
#  'Abner Mariri': 'artist/Abner-Mariri/2058850',
#  'ABNEW': 'artist/ABNEW/2137852854',
#  'Abney Park': 'artist/Abney-Park/509321',
#  'Abo': 'artist/Abo/2708192',
#  'Abomination': 'artist/Abomination/2755994',
#  'Abongwe Mbatha': 'artist/Abongwe-Mbatha/2137852823',
#  'Aborted': 'artist/Aborted/568178',
#  'Aborym': 'artist/Aborym/510429',
#  'Abou Debeing': 'artist/Abou-Debeing/3026694',
#  'Abou Tall': 'artist/Abou-Tall/2863482',
#  'About 2': 'artist/About-2/1809801',
#  'About a Mile': 'artist/About-a-Mile/1172008',
#  'About Group': 'artist/About-Group/2347705',
#  'Above': 'artist/Above/295180',
#  'Above & Beyond': 'artist/Above-%26-Beyond/368908',
#  'Above the Golden State': 'artist/Above-the-Golden-State/1065422',
#  'Above the Law': 'artist/Above-the-Law/3',
#  'Abra': 'artist/Abra/2904966',
#  'Abra Cadabra': 'artist/Abra-Cadabra/486036',
#  'Abra Moore': 'artist/Abra-Moore/144184',
#  'Abracadabra': 'artist/Abracadabra/203946',
#  'Abraham': 'artist/Abraham/481024',
#  'Abraham Burton': 'artist/Abraham-Burton/45101',
#  'Abraham Calleros': 'artist/Abraham-Calleros/1088492',
#  'Abraham Cloud': 'artist/Abraham-Cloud/211624',
#  'Abraham Laboriel': 'artist/Abraham-Laboriel/3143188',
#  'Abraham Laboriel, Sr.': 'artist/Abraham-Laboriel%2C-Sr./95904',
#  'Abraham Marder': 'artist/Abraham-Marder/2137856400',
#  'Abraham Mateo': 'artist/Abraham-Mateo/2302887',
#  'Abraham Rozanoff': 'artist/Abraham-Rozanoff/547860',
#  'Abraham Ruiz': 'artist/Abraham-Ruiz/2558410',
#  'Abraham Sarache': 'artist/Abraham-Sarache/2137856216',
#  'Abraham Vazquez': 'artist/Abraham-Vazquez/3528479',
#  'Abraham Velazquez': 'artist/Abraham-Velazquez/1040999',
#  'ABRAM': 'artist/ABRAM/2137852039',
#  'Abrams Brothers': 'artist/Abrams-Brothers/920923',
#  'Abrante & Caiko': 'artist/Abrante-%26-Caiko/2137859619',
#  'Abrasive Wheels': 'artist/Abrasive-Wheels/15257',
#  'Abraskadabra': 'artist/Abraskadabra/2137854878',
#  'Abraxas': 'artist/Abraxas/295181',
#  'Abreaction': 'artist/Abreaction/142423',
#  'Abreu': 'artist/Abreu/535512',
#  'Abril Luna': 'artist/Abril-Luna/2137860080',
#  'Abrildefresa': 'artist/Abrildefresa/2137857485',
#  'Abrupt': 'artist/Abrupt/1015741',
#  'ABS': 'artist/ABS/357211',
#  'Abs': 'artist/Abs/1003487',
#  'Abs Orchestra': 'artist/Abs-Orchestra/2919284',
#  'Absaloot': 'artist/Absaloot/1807161',
#  'Abscess': 'artist/Abscess/169315',
#  'Absent Friends': 'artist/Absent-Friends/890501',
#  'Absentstar': 'artist/Absentstar/923653',
#  'Absint': 'artist/Absint/2137847836',
#  'Absinthe': 'artist/Absinthe/2137852169',
#  'Absofacto': 'artist/Absofacto/2137850143',
#  'Absolom': 'artist/Absolom/363167',
#  'Absolut': 'artist/Absolut/471782',
#  'Absolute': 'artist/Absolute/12132',
#  'Absolute Beginner': 'artist/Absolute-Beginner/442717',
#  'Absolutely Fantastic': 'artist/Absolutely-Fantastic/1066561',
#  'Absolutely Free': 'artist/Absolutely-Free/2892899',
#  'Absoulute': 'artist/Absoulute/442285',
#  'Abstract Rude': 'artist/Abstract-Rude/175086',
#  'Abstract Truth': 'artist/Abstract-Truth/210714',
#  'Abstrakt Algebra': 'artist/Abstrakt-Algebra/1783891',
#  'Absu': 'artist/Absu/289641',
#  'Absurd': 'artist/Absurd/289849',
#  'Absurd Minds': 'artist/Absurd-Minds/553142',
#  'Absurdus': 'artist/Absurdus/395838',
#  'Absynthe Minded': 'artist/Absynthe-Minded/745947',
#  'Abu': 'artist/Abu/486173',
#  'Abu Bakr Salem': 'artist/Abu-Bakr-Salem/2137858092',
#  'Abudy': 'artist/Abudy/2137860196',
#  'Abundant Harvest Choir': 'artist/Abundant-Harvest-Choir/203949',
#  'Abused Majesty': 'artist/Abused-Majesty/830519',
#  'Abwärts': 'artist/Abw%C3%A4rts/15264',
#  'Abysm': 'artist/Abysm/732592',
#  'Abysmal Dawn': 'artist/Abysmal-Dawn/761151',
#  'Abyss': 'artist/Abyss/2082740',
#  'AC': 'artist/AC/781833',
#  'Ac': 'artist/Ac/925207',
#  'Ac Acoustics': 'artist/Ac-Acoustics/2137855780',
#  'AC Black': 'artist/AC-Black/12134',
#  'AC-Rock': 'artist/AC-Rock/428923',
#  'AC/DC': 'artist/AC-DC/3496',
#  'Aca Lukas': 'artist/Aca-Lukas/2137855077',
#  'Acab': 'artist/Acab/3383339',
#  'Academia OT II': 'artist/Academia-OT-II/781249',
#  'ACADEMY': 'artist/ACADEMY/2137853045',
#  'Academy Film Orchestra': 'artist/Academy-Film-Orchestra/276630',
#  'Academy of St. Martin-in-the-Fields': 'artist/Academy-of-St.-Martin-in-the-Fields/50300',
#  'Academy of St. Martin-in-the-Fields Chorus': 'artist/Academy-of-St.-Martin-in-the-Fields-Chorus/1372239',
#  'AcaFellas': 'artist/AcaFellas/1155556',
#  'Acafool': 'artist/Acafool/827147',
#  'Acappella': 'artist/Acappella/2186',
#  'Acapulco Tropical': 'artist/Acapulco-Tropical/36931',
#  'Acardipane': 'artist/Acardipane/449574',
#  'Accademia di Santa Cecilia Chorus': 'artist/Accademia-di-Santa-Cecilia-Chorus/1030541',
#  'Accademia di Santa Cecilia Orchestra': 'artist/Accademia-di-Santa-Cecilia-Orchestra/476578',
#  'Accademia Polifonica di Roma': 'artist/Accademia-Polifonica-di-Roma/384614',
#  'Accalra Johnson': 'artist/Accalra-Johnson/746624',
#  'Accardi/Gold': 'artist/Accardi-Gold/1050111',
#  'Accents': 'artist/Accents/2287766',
#  'Accentus Austria': 'artist/Accentus-Austria/278950',
#  'Accept': 'artist/Accept/3498',
#  'Acceptance': 'artist/Acceptance/508832',
#  'Access': 'artist/Access/403000',
#  'Accessory': 'artist/Accessory/553140',
#  'Accidental Superhero': 'artist/Accidental-Superhero/559573',
#  'Acción Sánchez': 'artist/Acci%C3%B3n-S%C3%A1nchez/590850',
#  'Accordeonistes Medinger': 'artist/Accordeonistes-Medinger/1055915',
#  'According To John': 'artist/According-To-John/474782',
#  'Accrophone': 'artist/Accrophone/747260',
#  'Accuface': 'artist/Accuface/363410',
#  'Accursed': 'artist/Accursed/15274',
#  'Acd': 'artist/Acd/370025',
#  'Acda en De Munnik': 'artist/Acda-en-De-Munnik/320425',
#  'Ace': 'artist/Ace/365747',
#  'Ace & Quan': 'artist/Ace-%26-Quan/486206',
#  'Ace Boogie': 'artist/Ace-Boogie/1669711',
#  'Ace Cannon': 'artist/Ace-Cannon/16279',
#  'Ace Deuce': 'artist/Ace-Deuce/201357',
#  'Ace Diamond': 'artist/Ace-Diamond/1035373',
#  'Ace Enders': 'artist/Ace-Enders/2100816',
#  'Ace Frehley': 'artist/Ace-Frehley/4311',
#  'Ace Gutta': 'artist/Ace-Gutta/1050632',
#  'Ace Harris': 'artist/Ace-Harris/219078',
#  'Ace Hood': 'artist/Ace-Hood/1056083',
#  'Ace in the Hole Band': 'artist/Ace-in-the-Hole-Band/50310',
#  "Ace O'Donnell": 'artist/Ace-O%27Donnell/203409',
#  'Ace of Base': 'artist/Ace-of-Base/43297',
#  'Ace of Cups': 'artist/Ace-of-Cups/2137845826',
#  'Ace Primo': 'artist/Ace-Primo/2700938',
#  'Ace Spectrum': 'artist/Ace-Spectrum/15277',
#  'Ace Tee': 'artist/Ace-Tee/3367682',
#  'Ace Troubleshooter': 'artist/Ace-Troubleshooter/451416',
#  'Ace Wilder': 'artist/Ace-Wilder/2886788',
#  'Ace Young': 'artist/Ace-Young/815137',
#  'Ace-Dawg': 'artist/Ace-Dawg/2203467',
#  'Aceituna Sin Hueso': 'artist/Aceituna-Sin-Hueso/819742',
#  'AcentOh': 'artist/AcentOh/2137858498',
#  'Acero': 'artist/Acero/1041006',
#  'Aces Combo': 'artist/Aces-Combo/201358',
#  'Aces High': 'artist/Aces-High/659884',
#  'Acetone': 'artist/Acetone/142426',
#  'Aceyalone': 'artist/Aceyalone/169316',
#  'Acheron': 'artist/Acheron/36933',
#  'Achie Touf': 'artist/Achie-Touf/3556270',
#  'Achille Lauro': 'artist/Achille-Lauro/925217',
#  'Achim Brugger': 'artist/Achim-Brugger/1148430',
#  'Achim Kaufmann': 'artist/Achim-Kaufmann/250364',
#  'Achim Petry': 'artist/Achim-Petry/1021827',
#  'Achim Reichel': 'artist/Achim-Reichel/20129',
#  'Achim Schultz': 'artist/Achim-Schultz/889466',
#  'Acho Estol': 'artist/Acho-Estol/341273',
#  'Achtabahn': 'artist/Achtabahn/2137848293',
#  'AchtVier': 'artist/AchtVier/2838701',
#  'Achyronthia': 'artist/Achyronthia/2361241',
#  'ACI Muzik': 'artist/ACI-Muzik/743894',
#  'Acid': 'artist/Acid/2137845163',
#  'Acid Android': 'artist/Acid-Android/849724',
#  'Acid Bath': 'artist/Acid-Bath/44863',
#  'Acid Black Cherry': 'artist/Acid-Black-Cherry/1034911',
#  'Acid Dad': 'artist/Acid-Dad/2137859954',
#  'Acid Death': 'artist/Acid-Death/393212',
#  'Acid Drinkers': 'artist/Acid-Drinkers/295184',
#  'Acid Factor': 'artist/Acid-Factor/216000',
#  'Acid Horse': 'artist/Acid-Horse/12137',
#  'Acid House Kings': 'artist/Acid-House-Kings/310306',
#  'Acid J': 'artist/Acid-J/1088504',
#  'Acid Mondays': 'artist/Acid-Mondays/2165292',
#  'Acid Reign': 'artist/Acid-Reign/2137848825',
#  'Acid Witch': 'artist/Acid-Witch/1170317',
#  'Acid0sis': 'artist/Acid0sis/2472656',
#  'Acida Corporation': 'artist/Acida-Corporation/2581717',
#  'Acidman': 'artist/Acidman/825931',
#  'Acie Cargill': 'artist/Acie-Cargill/510296',
#  'Acies Christi': 'artist/Acies-Christi/1015720',
#  'Ack Van Rooyen': 'artist/Ack-Van-Rooyen/120763',
#  'Ackeejuice Rockers': 'artist/Ackeejuice-Rockers/3252426',
#  'Acker Bilk': 'artist/Acker-Bilk/6116',
#  'Acker Bilk & His Paramount Jazz Band': 'artist/Acker-Bilk-%26-His-Paramount-Jazz-Band/545602',
#  'Acker Bilk His Clarinet & Strings': 'artist/Acker-Bilk-His-Clarinet-%26-Strings/811058',
#  'Acne Records': 'artist/Acne-Records/893618',
#  'Aco': 'artist/Aco/624181',
#  'Acoustic': 'artist/Acoustic/2519579',
#  'Acoustic Alchemy': 'artist/Acoustic-Alchemy/5977',
#  'Acoustic Blue': 'artist/Acoustic-Blue/1133864',
#  'Acoustic Duo': 'artist/Acoustic-Duo/975765',
#  'Acoustic Eidolon': 'artist/Acoustic-Eidolon/1897816',
#  'Acoustic Guitar Summit': 'artist/Acoustic-Guitar-Summit/484071',
#  'Acoustic Journey': 'artist/Acoustic-Journey/893946',
#  'Acoustic Junction': 'artist/Acoustic-Junction/36937',
#  'Acoustic Ladyland': 'artist/Acoustic-Ladyland/746528',
#  'Acoustic Mania': 'artist/Acoustic-Mania/810906',
#  'Acoustic Philosophy': 'artist/Acoustic-Philosophy/638808',
#  'Acoustic Serenade': 'artist/Acoustic-Serenade/705102',
#  'Acoustic Shadows of the Blue & Gray': 'artist/Acoustic-Shadows-of-the-Blue-%26-Gray/895260',
#  'Acoustic Soul': 'artist/Acoustic-Soul/982293',
#  'Acoustic Sound Orchestra': 'artist/Acoustic-Sound-Orchestra/868451',
#  'Acoustic Strawbs': 'artist/Acoustic-Strawbs/866035',
#  'Acoustic Warriors': 'artist/Acoustic-Warriors/895510',
#  'Acoustic Worship': 'artist/Acoustic-Worship/1808154',
#  'Acoustic X': 'artist/Acoustic-X/705104',
#  'Acousticsol': 'artist/Acousticsol/554628',
#  'Acoustique Parfum': 'artist/Acoustique-Parfum/1062945',
#  'Acoustitherapy': 'artist/Acoustitherapy/893641',
#  'Acoustix': 'artist/Acoustix/203954',
#  'Acquire the Fire': 'artist/Acquire-the-Fire/437172',
#  'Acres': 'artist/Acres/441379',
#  'Acretongue': 'artist/Acretongue/2137858736',
#  'Acrimony': 'artist/Acrimony/276037',
#  'Acrobat Quad': 'artist/Acrobat-Quad/1770051',
#  'Acroma': 'artist/Acroma/558597',
#  'Acrophet': 'artist/Acrophet/12139',
#  'Across Five Aprils': 'artist/Across-Five-Aprils/560291',
#  'Across the Fields': 'artist/Across-the-Fields/705109',
#  'Across the Sky': 'artist/Across-the-Sky/561518',
#  'Acrostichon': 'artist/Acrostichon/36940',
#  'Act': 'artist/Act/225161',
#  'Action': 'artist/Action/1054494',
#  'Action Action': 'artist/Action-Action/674934',
#  'Action Bronson': 'artist/Action-Bronson/2161312',
#  'Action Camp': 'artist/Action-Camp/2137855195',
#  'Action Item': 'artist/Action-Item/2471364',
#  'Action Man': 'artist/Action-Man/1093674',
#  'Action Plus': 'artist/Action-Plus/748763',
#  'Action Swingers': 'artist/Action-Swingers/12140',
#  'Action/Adventure': 'artist/Action-Adventure/2137857910',
#  'ActionReaction': 'artist/ActionReaction/762794',
#  'Actionslacks': 'artist/Actionslacks/203956',
#  'Actitud Maria Marta': 'artist/Actitud-Maria-Marta/475044',
#  'Activ': 'artist/Activ/2137855965',
#  'Active Child': 'artist/Active-Child/2094681',
#  'Actress': 'artist/Actress/859118',
#  'Acts': 'artist/Acts/705114',
#  'Acumen Nation': 'artist/Acumen-Nation/203957',
#  'Aczino': 'artist/Aczino/2137851962',
#  'AD': 'artist/AD/859123',
#  'Ad': 'artist/Ad/15242',
#  'Ad de Feyter': 'artist/Ad-de-Feyter/330366',
#  'Ad Hominem': 'artist/Ad-Hominem/816563',
#  'Ad Infinitum': 'artist/Ad-Infinitum/2137848821',
#  "Ad Men's": 'artist/Ad-Men%27s/2530131',
#  'Ad Rock': 'artist/Ad-Rock/1808700',
#  'Ad the Voice': 'artist/Ad-the-Voice/911121',
#  'Ad-Rock': 'artist/Ad-Rock/248031',
#  'AD5': 'artist/AD5/705030',
#  'Ada': 'artist/Ada/551857',
#  'Ada Band': 'artist/Ada-Band/1071829',
#  'Ada C. Washington': 'artist/Ada-C.-Washington/1088515',
#  'Ada DeLuque': 'artist/Ada-DeLuque/585856',
#  'Ada Dyer': 'artist/Ada-Dyer/4146',
#  'Ada Jones': 'artist/Ada-Jones/188425',
#  'Ada Kahn': 'artist/Ada-Kahn/819194',
#  'Ada Montellanico': 'artist/Ada-Montellanico/291001',
#  'Ada Moore': 'artist/Ada-Moore/7166',
#  'Ada Rovatti': 'artist/Ada-Rovatti/344749',
#  'Adagio': 'artist/Adagio/1008832',
#  'Adailton Couto': 'artist/Adailton-Couto/2137853499',
#  'Adair': 'artist/Adair/760775',
#  'Adair Cardoso': 'artist/Adair-Cardoso/2401341',
#  'Adakain': 'artist/Adakain/1088516',
#  'Adakanbo': 'artist/Adakanbo/2137858543',
#  'Adalbert Luczkowski': 'artist/Adalbert-Luczkowski/2120063',
#  'Adalberto Álvarez': 'artist/Adalberto-%C3%81lvarez/42766',
#  'Adalberto Álvarez y Su Son': 'artist/Adalberto-%C3%81lvarez-y-Su-Son/303770',
#  'Adalberto Santiago': 'artist/Adalberto-Santiago/122018',
#  'Adalgisa Pantaleon': 'artist/Adalgisa-Pantaleon/2137848083',
#  'Adaline': 'artist/Adaline/2137845709',
#  'Adam': 'artist/Adam/893666',
#  'Adam "Swannee" Swann': 'artist/Adam-%22Swannee%22-Swann/203827',
#  'Adam & Amy': 'artist/Adam-%26-Amy/2229111',
#  'Adam & Eve': 'artist/Adam-%26-Eve/794086',
#  'Adam & The Ants': 'artist/Adam-%26-The-Ants/183542',
#  'Adam Abraham': 'artist/Adam-Abraham/1218169',
#  'Adam Again': 'artist/Adam-Again/30396',
#  'Adam Agee': 'artist/Adam-Agee/695899',
#  'Adam Agin': 'artist/Adam-Agin/2137857300',
#  'Adam and Andrew': 'artist/Adam-and-Andrew/893667',
#  'Adam and the Ants': 'artist/Adam-and-the-Ants/2137844804',
#  'Adam and the Weight': 'artist/Adam-and-the-Weight/705123',
#  'Adam Anders': 'artist/Adam-Anders/339460',
#  'Adam Ant': 'artist/Adam-Ant/3560',
#  'Adam Argyle': 'artist/Adam-Argyle/917195',
#  'Adam Baldych': 'artist/Adam-Baldych/2639923',
#  'Adam Benjamin': 'artist/Adam-Benjamin/925241',
#  'Adam Berkson': 'artist/Adam-Berkson/231419',
#  'Adam Beyer': 'artist/Adam-Beyer/277358',
#  'Adam Birnbaum': 'artist/Adam-Birnbaum/1611679',
#  'Adam Boucher': 'artist/Adam-Boucher/897687',
#  'Adam Brand': 'artist/Adam-Brand/337658',
#  'Adam Brock': 'artist/Adam-Brock/925245',
#  'Adam Buchwald': 'artist/Adam-Buchwald/640320',
#  'Adam Calhoun': 'artist/Adam-Calhoun/3387672',
#  'Adam Cappa': 'artist/Adam-Cappa/2560469',
#  'Adam Carroll': 'artist/Adam-Carroll/1049343',
#  'Adam Caulfield': 'artist/Adam-Caulfield/707739',
#  'Adam Chance': 'artist/Adam-Chance/2299116',
#  'Adam Chanler-Berat': 'artist/Adam-Chanler-Berat/1184112',
#  'Adam Clayton': 'artist/Adam-Clayton/64969',
#  'Adam Cohen': 'artist/Adam-Cohen/279480',
#  'Adam Crabb': 'artist/Adam-Crabb/618920',
#  'Adam Craig': 'artist/Adam-Craig/893677',
#  'Adam Cruz': 'artist/Adam-Cruz/67654',
#  'Adam Cunningham': 'artist/Adam-Cunningham/908950',
#  'Adam Czerwinski': 'artist/Adam-Czerwinski/893678',
#  'Adam Daniel': 'artist/Adam-Daniel/371439',
#  'Adam Dannheisser': 'artist/Adam-Dannheisser/1564287',
#  'Adam Davenport': 'artist/Adam-Davenport/756542',
#  'Adam del Monte': 'artist/Adam-del-Monte/368086',
#  'Adam Derry': 'artist/Adam-Derry/709260',
#  'Adam Devine': 'artist/Adam-Devine/2701170',
#  'Adam Doleac': 'artist/Adam-Doleac/2137846692',
#  'Adam Driver': 'artist/Adam-Driver/2842665',
#  'Adam Duritz': 'artist/Adam-Duritz/145217',
#  'Adam Durvitz': 'artist/Adam-Durvitz/2298806',
#  'Adam Ezra': 'artist/Adam-Ezra/2137855723',
#  'Adam F': 'artist/Adam-F/199874',
#  'Adam Faith': 'artist/Adam-Faith/17413',
#  'Adam Falcon': 'artist/Adam-Falcon/429884',
#  'Adam Fears': 'artist/Adam-Fears/1001256',
#  'Adam Fenton': 'artist/Adam-Fenton/241597',
#  'Adam Fleming': 'artist/Adam-Fleming/557020',
#  'Adam Freeland': 'artist/Adam-Freeland/350709',
#  'Adam French': 'artist/Adam-French/2033446',
#  'Adam Garcia': 'artist/Adam-Garcia/346322',
#  'Adam Glasser': 'artist/Adam-Glasser/341755',
#  'Adam Gontier': 'artist/Adam-Gontier/817555',
#  'Adam Grahn': 'artist/Adam-Grahn/2137848907',
#  'Adam Green': 'artist/Adam-Green/279683',
#  'Adam Gregory': 'artist/Adam-Gregory/478063',
#  'Adam Grey': 'artist/Adam-Grey/2225473',
#  'Adam Guettel': 'artist/Adam-Guettel/202352',
#  'Adam Gussow': 'artist/Adam-Gussow/82972',
#  'Adam Hambrick': 'artist/Adam-Hambrick/2137858044',
#  'Adam Harvey': 'artist/Adam-Harvey/698129',
#  'Adam Hemming': 'artist/Adam-Hemming/492359',
#  'Adam Hicks': 'artist/Adam-Hicks/86510',
#  'Adam Hoffman': 'artist/Adam-Hoffman/893683',
#  'Adam Hood': 'artist/Adam-Hood/645187',
#  'Adam Hurst': 'artist/Adam-Hurst/620361',
#  'Adam Irigoyen': 'artist/Adam-Irigoyen/2599885',
#  'Adam Jackson': 'artist/Adam-Jackson/188216',
#  'Adam Joseph': 'artist/Adam-Joseph/618423',
#  'Adam K.': 'artist/Adam-K./728470',
#  'Adam Kanyama': 'artist/Adam-Kanyama/2613331',
#  'Adam Kesher': 'artist/Adam-Kesher/984799',
#  'Adam Klein': 'artist/Adam-Klein/155461',
#  'Adam Kolker': 'artist/Adam-Kolker/94836',
#  'Adam Lambert': 'artist/Adam-Lambert/1152615',
#  'Adam Lazzara': 'artist/Adam-Lazzara/749156',
#  'Adam Levin': 'artist/Adam-Levin/640629',
#  'Adam Levine': 'artist/Adam-Levine/3086422',
#  'Adam Levy': 'artist/Adam-Levy/484195',
#  'Adam Locklin': 'artist/Adam-Locklin/703836',
#  'Adam Lopez': 'artist/Adam-Lopez/715022',
#  'Adam Makowicz': 'artist/Adam-Makowicz/7026',
#  'Adam Mansell Orchestra': 'artist/Adam-Mansell-Orchestra/179003',
#  'Adam Marano': 'artist/Adam-Marano/222748',
#  'Adam Markiewicz': 'artist/Adam-Markiewicz/3011262',
#  'Adam Marsland': 'artist/Adam-Marsland/255525',
#  'Adam McKnight': 'artist/Adam-McKnight/2019891',
#  'Adam Miller': 'artist/Adam-Miller/105910',
#  'Adam Mugavero': 'artist/Adam-Mugavero/716681',
#  'Adam Muller': 'artist/Adam-Muller/815318',
#  'Adam Naas': 'artist/Adam-Naas/3229192',
#  'Adam Niewood': 'artist/Adam-Niewood/665187',
#  'Adam Nussbaum': 'artist/Adam-Nussbaum/108540',
#  'Adam Pascal': 'artist/Adam-Pascal/344124',
#  'Adam Paul Williams': 'artist/Adam-Paul-Williams/925261',
#  'Adam Plack': 'artist/Adam-Plack/159660',
#  'Adam Power': 'artist/Adam-Power/559008',
#  'Adam Rafferty': 'artist/Adam-Rafferty/194687',
#  'Adam Richman': 'artist/Adam-Richman/677427',
#  'Adam Rickitt': 'artist/Adam-Rickitt/2137848013',
#  'Adam Rodgers': 'artist/Adam-Rodgers/344658',
#  'Adam Rogers': 'artist/Adam-Rogers/119791',
#  'Adam Rom': 'artist/Adam-Rom/3541810',
#  'Adam Romeyn Nesbitt': 'artist/Adam-Romeyn-Nesbitt/658832',
#  'Adam Sandler': 'artist/Adam-Sandler/143392',
#  'Adam Schlesinger': 'artist/Adam-Schlesinger/219735',
#  'Adam Schmitt': 'artist/Adam-Schmitt/26935',
#  'Adam Shelton': 'artist/Adam-Shelton/2796920',
#  'Adam Sky': 'artist/Adam-Sky/922228',
#  'Adam Stachowiak': 'artist/Adam-Stachowiak/2137858697',
#  'Adam Steffey': 'artist/Adam-Steffey/128258',
#  'Adam Swanson': 'artist/Adam-Swanson/893699',
#  'Adam Tas': 'artist/Adam-Tas/2137846103',
#  'Adam Tensta': 'artist/Adam-Tensta/1015171',
#  'Adam Trent': 'artist/Adam-Trent/378554',
#  'Adam Trigger': 'artist/Adam-Trigger/3191489',
#  "Adam und Die Micky's": 'artist/Adam-und-Die-Micky%27s/868458',
#  'Adam Wade': 'artist/Adam-Wade/283376',
#  'Adam Wakefield': 'artist/Adam-Wakefield/3209801',
#  'Adam Wakeman': 'artist/Adam-Wakeman/135413',
#  'Adam Watts': 'artist/Adam-Watts/591825',
#  'Adam West': 'artist/Adam-West/295187',
#  'Adam Woods': 'artist/Adam-Woods/139607',
#  'Adam Wylie': 'artist/Adam-Wylie/473405',
#  'Adam X': 'artist/Adam-X/224516',
#  'Adam Young': 'artist/Adam-Young/320306',
#  'Adama': 'artist/Adama/750189',
#  'Adama Diallo': 'artist/Adama-Diallo/2230344',
#  'Adamantium': 'artist/Adamantium/355023',
#  'Adamo': 'artist/Adamo/1001078',
#  'Adams': 'artist/Adams/144751',
#  'Adams/Pullen Quartet': 'artist/Adams-Pullen-Quartet/142427',
#  'Adamski': 'artist/Adamski/12142',
#  'Adan "Chalino" Sanchez': 'artist/Adan-%22Chalino%22-Sanchez/206465',
#  'Adan Jodorowsky': 'artist/Adan-Jodorowsky/2136467',
#  'Adano': 'artist/Adano/705140',
#  'Adanowsky': 'artist/Adanowsky/1010562',
#  'Adão Negro': 'artist/Ad%C3%A3o-Negro/2137848966',
#  'Adassa': 'artist/Adassa/486708',
#  'Addal': 'artist/Addal/3267507',
#  'Adderley Brothers': 'artist/Adderley-Brothers/425258',
#  'Addict': 'artist/Addict/294365',
#  'Addiction Crew': 'artist/Addiction-Crew/830551',
#  'Addikt102': 'artist/Addikt102/3534173',
#  'Addison Agen': 'artist/Addison-Agen/3394808',
#  'Addison Farmer': 'artist/Addison-Farmer/75137',
#  'Addison Groove Project': 'artist/Addison-Groove-Project/510585',
#  'Addison Rae ': 'artist/Addison-Rae-/2137854133',
#  'Addison Road': 'artist/Addison-Road/893716',
#  'Addrisi Brothers': 'artist/Addrisi-Brothers/15297',
#  'Addy Van Der Zwan': 'artist/Addy-Van-Der-Zwan/335561',
#  'Ade': 'artist/Ade/1802604',
#  'Ade Fenton': 'artist/Ade-Fenton/403823',
#  'Ade Omotayo': 'artist/Ade-Omotayo/841624',
#  'Ade Putra': 'artist/Ade-Putra/2917088',
#  'Adeaze': 'artist/Adeaze/830552',
#  'Adeem': 'artist/Adeem/653530',
#  'Adeena': 'artist/Adeena/2137859852',
#  'Adekunle Gold': 'artist/Adekunle-Gold/50',
#  'Adel': 'artist/Adel/3535786',
#  'Adel Al Mukhtar': 'artist/Adel-Al-Mukhtar/2137859182',
#  'Adel Khalil': 'artist/Adel-Khalil/917755',
#  'Adel Tawil': 'artist/Adel-Tawil/997991',
#  'Adela Dalto': 'artist/Adela-Dalto/68443',
#  'Adelaide Davis': 'artist/Adelaide-Davis/583970',
#  'Adelaide Ferreira': 'artist/Adelaide-Ferreira/975769',
#  'Adelaide Hall': 'artist/Adelaide-Hall/8680',
#  'Adelaide Robbins': 'artist/Adelaide-Robbins/344631',
#  'Adelaide Ruble': 'artist/Adelaide-Ruble/742112',
#  'Adele': 'artist/Adele/861756',
#  'Adele Armin': 'artist/Adele-Armin/52436',
#  'Adele Astaire': 'artist/Adele-Astaire/339556',
#  'Adele Girard': 'artist/Adele-Girard/173378',
#  'Adele Girard Marsala': 'artist/Adele-Girard-Marsala/343311',
#  'Adele Nicols': 'artist/Adele-Nicols/717056',
#  'Adele Taylor': 'artist/Adele-Taylor/2541167',
#  'Adele Urbiztondo': 'artist/Adele-Urbiztondo/1134112',
#  'Adele Zane': 'artist/Adele-Zane/463782',
#  'Adelén': 'artist/Adel%C3%A9n/2830037',
#  'Adeline': 'artist/Adeline/2137850189',
#  'Adelitas Way': 'artist/Adelitas-Way/1155617',
#  'Adelphi': 'artist/Adelphi/291581',
#  'Adelphi Music Factory': 'artist/Adelphi-Music-Factory/3573748',
#  'Adem': 'artist/Adem/438674',
#  'Adema': 'artist/Adema/507767',
#  'Aden': 'artist/Aden/2904636',
#  'Aden X Asme': 'artist/Aden-X-Asme/3536994',
#  'Aden X Olson': 'artist/Aden-X-Olson/3385707',
#  'Adeniyi Allen-Taylor': 'artist/Adeniyi-Allen-Taylor/1148328',
#  'Adept': 'artist/Adept/925286',
#  'Adequate Seven': 'artist/Adequate-Seven/558993',
#  'Adesse': 'artist/Adesse/3135076',
#  'Adestria': 'artist/Adestria/2576573',
#  'Adeva': 'artist/Adeva/12143',
#  'Adewale Ayuba': 'artist/Adewale-Ayuba/204086',
#  'Adexe': 'artist/Adexe/3375183',
#  'Adexe & Nau': 'artist/Adexe-%26-Nau/2137845253',
#  'ADF Samski': 'artist/ADF-Samski/2137849654',
#  'Adham Assaad': 'artist/Adham-Assaad/2137846874',
#  'Adi Braun': 'artist/Adi-Braun/560366',
#  'Adi L Hasla': 'artist/Adi-L-Hasla/3131146',
#  'Adi Nowak': 'artist/Adi-Nowak/3330824',
#  'Adi Ulmansky': 'artist/Adi-Ulmansky/2137860120',
#  'Adi Yeshaya': 'artist/Adi-Yeshaya/228280',
#  'Adia Reid': 'artist/Adia-Reid/3149022',
#  'Adia Victoria': 'artist/Adia-Victoria/2137859913',
#  'Adichie': 'artist/Adichie/486818',
#  'Adicta': 'artist/Adicta/664179',
#  'Adie': 'artist/Adie/828613',
#  'Adie Camp': 'artist/Adie-Camp/883547',
#  'Adie Feuerstein': 'artist/Adie-Feuerstein/2288281',
#  'Adiemus': 'artist/Adiemus/169319',
#  'Adime': 'artist/Adime/2638154',
#  'Adina Butar': 'artist/Adina-Butar/2701320',
#  'Adina Edwards': 'artist/Adina-Edwards/524278',
#  'Adina Howard': 'artist/Adina-Howard/141664',
#  'Adinda Adi': 'artist/Adinda-Adi/3419260',
#  ...}

# %% [markdown]
#     For each artist, grab the songs, saving results to a dataframe

# %%
lyrics_columns = ['Artist Name', 'Artist URL', 'Song Title', 'Song URL', 'Song Lyrics']

artist_df = pd.DataFrame(columns = lyrics_columns, dtype = str)
artist_df
# Out:
# Empty DataFrame
# Columns: [Artist Name, Artist URL, Song Title, Song URL, Song Lyrics]
# Index: []

# %%
for key in tqdm.tqdm(artists_dict):

    artist_name = key
    artist_subdir = artists_dict[key]
    artist_url = LYRICS_URL + artist_subdir
    artist_html = requests.get(artist_url).text
    artist_soup = BeautifulSoup(artist_html, 'html5lib')
    
    for i in range(len(artist_soup.find_all('table', class_=re.compile("tdata")))):

        artist_link = artist_soup.find_all('table', class_=re.compile("tdata"))[i].find('tbody').a

        lst = []

        # 'Artist Name', 'Artist URL', 'Song Title', 'Song URL', 'Song Lyrics'
        lst.append(artist_name)
        lst.append(artist_subdir)
        lst.append(artist_link.text)
        lst.append(artist_link.get('href'))
        lst.append('')

        artist_df = artist_df.append(pd.Series(lst, index = lyrics_columns), ignore_index=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 128917/128917 [63:22:45<00:00,  1.77s/it]

# %%
artist_df.to_csv(DATA_PATH + "artist_scrape_no_lyrics.csv", index=False)

# %%
artist_df
# Out:
#                 Artist Name                            Artist URL  \
# 0                       A B                     artist/A-B/472398
# 1               A Bad Think         artist/A-Bad-Think/2137849593
# 2        A Baffled Republic  artist/A-Baffled-Republic/2137849643
# 3               A Banca 021         artist/A-Banca-021/2137850524
# 4         A Band Called "O"    artist/A-Band-Called-%22O%22/19641
# ...                     ...                                   ...
# 1352583             ZZ Ward                artist/ZZ-Ward/2633167
# 1352584             ZZ Ward                artist/ZZ-Ward/2633167
# 1352585             ZZ Ward                artist/ZZ-Ward/2633167
# 1352586             ZZ Ward                artist/ZZ-Ward/2633167
# 1352587              zzoilo              artist/zzoilo/2137859922
#
#                                                 Song Title  \
# 0                                 Con el Tic Tac del Reloj
# 1                                             Now You Know
# 2                               Bad Boys (Move in Silence)
# 3                                               Cor de Mel
# 4                                                 Sleeping
# ...                                                    ...
# 1352583                                      Hold My Heart
# 1352584  Move Like U Stole It [Paul Oakenfold Remix - I...
# 1352585                                         Cannonball
# 1352586                                         Cryin Wolf
# 1352587                                  Mon Amour [Remix]
#
#                                                   Song URL Song Lyrics
# 0              /lyric/3455846/A+B/Con+el+Tic+Tac+del+Reloj
# 1                 /lyric/36417131/A+Bad+Think/Now+You+Know
# 2        /lyric/2262594/A+Baffled+Republic/Bad+Boys+%28...
# 3                   /lyric/37798632/A+Banca+021/Cor+de+Mel
# 4             /lyric/637199/A+Band+Called+%22O%22/Sleeping
# ...                                                    ...         ...
# 1352583              /lyric/35830531/ZZ+Ward/Hold+My+Heart
# 1352584  /lyric/29960072/ZZ+Ward/Move+Like+U+Stole+It+%...
# 1352585                 /lyric/35448627/ZZ+Ward/Cannonball
# 1352586                 /lyric/36049908/ZZ+Ward/Cryin+Wolf
# 1352587       /lyric/38837282/zzoilo/Mon+Amour+%5BRemix%5D
#
# [1352588 rows x 5 columns]
